# %%
#loading pandas package to load and clean the data
import pandas as pd
#importing libraries needed for regression and visualization
import numpy as np
import seaborn as sns
import statsmodels.formula.api as smf
import matplotlib.pylab as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /anaconda/lib/python3.6/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['plt', 'figsize', 'Polygon', 'mod']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# During this lab we will work with American community servey and crime data to establish and visualize relations between wealth, population and crime on different spatial scales, including county, state and city.

# %% [markdown]
# ### Loading Demographics data (American Community Servey Data) obtained from the social explorer

# %%
demographics = pd.read_csv('data2/R11460953_SL050.csv', encoding = "latin-1")
demographics.head()
# Out:
#    Geo_FIPS     Geo_GEOID                 Geo_NAME                Geo_QName  \
# 0      1001  05000US01001  Autauga County, Alabama  Autauga County, Alabama
# 1      1003  05000US01003  Baldwin County, Alabama  Baldwin County, Alabama
# 2      1005  05000US01005  Barbour County, Alabama  Barbour County, Alabama
# 3      1007  05000US01007     Bibb County, Alabama     Bibb County, Alabama
# 4      1009  05000US01009   Blount County, Alabama   Blount County, Alabama
#
#   Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  \
# 0         al          50            0      ACSSF            13     NaN
# 1         al          50            0      ACSSF            14     NaN
# 2         al          50            0      ACSSF            15     NaN
# 3         al          50            0      ACSSF            16     NaN
# 4         al          50            0      ACSSF            17     NaN
#
#       ...       Geo_PUMA1  SE_T001_001  SE_T002_001  SE_T002_002  SE_T002_003  \
# 0     ...             NaN        55136        55136     92.75346   594.436089
# 1     ...             NaN       191205       191205    120.27100  1589.784070
# 2     ...             NaN        27119        27119     30.64722   884.876304
# 3     ...             NaN        22653        22653     36.38555   622.582332
# 4     ...             NaN        57645        57645     89.40315   644.775905
#
#    SE_T003_001  SE_T003_002  SE_T003_003  SE_T057_001  SE_T083_001
# 0     604.3882     594.4361     9.952067        52475        24644
# 1    2027.3110    1589.7840   437.527200        50183        26851
# 2     904.5153     884.8763    19.638980        35634        17350
# 3     626.1689     622.5823     3.586525        37984        18110
# 4     650.6282     644.7759     5.852321        44409        20501
#
# [5 rows x 64 columns]

# %% [markdown]
# Selecting requisite data from the dataframe and renaming the columns

# %%
demographics.columns
# Out:
# Index(['Geo_FIPS', 'Geo_GEOID', 'Geo_NAME', 'Geo_QName', 'Geo_STUSAB',
#        'Geo_SUMLEV', 'Geo_GEOCOMP', 'Geo_FILEID', 'Geo_LOGRECNO', 'Geo_US',
#        'Geo_REGION', 'Geo_DIVISION', 'Geo_STATECE', 'Geo_STATE', 'Geo_COUNTY',
#        'Geo_COUSUB', 'Geo_PLACE', 'Geo_PLACESE', 'Geo_TRACT', 'Geo_BLKGRP',
#        'Geo_CONCIT', 'Geo_AIANHH', 'Geo_AIANHHFP', 'Geo_AIHHTLI', 'Geo_AITSCE',
#        'Geo_AITS', 'Geo_ANRC', 'Geo_CBSA', 'Geo_CSA', 'Geo_METDIV', 'Geo_MACC',
#        'Geo_MEMI', 'Geo_NECTA', 'Geo_CNECTA', 'Geo_NECTADIV', 'Geo_UA',
#        'Geo_UACP', 'Geo_CDCURR', 'Geo_SLDU', 'Geo_SLDL', 'Geo_VTD',
#        'Geo_ZCTA3', 'Geo_ZCTA5', 'Geo_SUBMCD', 'Geo_SDELM', 'Geo_SDSEC',
#        'Geo_SDUNI', 'Geo_UR', 'Geo_PCI', 'Geo_TAZ', 'Geo_UGA', 'Geo_BTTR',
#        'Geo_BTBG', 'Geo_PUMA5', 'Geo_PUMA1', 'SE_T001_001', 'SE_T002_001',
#        'SE_T002_002', 'SE_T002_003', 'SE_T003_001', 'SE_T003_002',
#        'SE_T003_003', 'SE_T057_001', 'SE_T083_001'],
#       dtype='object')

# %%
demographics = demographics[[ u'Geo_GEOID', u'Geo_NAME', u'Geo_QName', u'Geo_COUNTY',\
                             u'SE_T001_001', u'SE_T002_002', u'SE_T002_003', u'SE_T057_001', u'SE_T083_001']]

demographics.rename(columns={u'SE_T001_001' : 'Population',\
                             u'SE_T002_002' : 'Population Density', \
                             u'SE_T002_003' : 'Area',\
                             u'SE_T057_001' : 'Median household income',\
                             u'SE_T083_001' : 'Per capita income'}, inplace=True)

# %%
demographics.head()
# Out:
#       Geo_GEOID                 Geo_NAME                Geo_QName  Geo_COUNTY  \
# 0  05000US01001  Autauga County, Alabama  Autauga County, Alabama           1
# 1  05000US01003  Baldwin County, Alabama  Baldwin County, Alabama           3
# 2  05000US01005  Barbour County, Alabama  Barbour County, Alabama           5
# 3  05000US01007     Bibb County, Alabama     Bibb County, Alabama           7
# 4  05000US01009   Blount County, Alabama   Blount County, Alabama           9
#
#    Population  Population Density         Area  Median household income  \
# 0       55136            92.75346   594.436089                    52475
# 1      191205           120.27100  1589.784070                    50183
# 2       27119            30.64722   884.876304                    35634
# 3       22653            36.38555   622.582332                    37984
# 4       57645            89.40315   644.775905                    44409
#
#    Per capita income
# 0              24644
# 1              26851
# 2              17350
# 3              18110
# 4              20501

# %%
#extract state number for future use
demographics['Geo_STATE']=demographics['Geo_GEOID'].apply(lambda x: x[-5:-3])

# %%
demographics.head()
# Out:
#       Geo_GEOID                 Geo_NAME                Geo_QName  Geo_COUNTY  \
# 0  05000US01001  Autauga County, Alabama  Autauga County, Alabama           1
# 1  05000US01003  Baldwin County, Alabama  Baldwin County, Alabama           3
# 2  05000US01005  Barbour County, Alabama  Barbour County, Alabama           5
# 3  05000US01007     Bibb County, Alabama     Bibb County, Alabama           7
# 4  05000US01009   Blount County, Alabama   Blount County, Alabama           9
#
#    Population  Population Density         Area  Median household income  \
# 0       55136            92.75346   594.436089                    52475
# 1      191205           120.27100  1589.784070                    50183
# 2       27119            30.64722   884.876304                    35634
# 3       22653            36.38555   622.582332                    37984
# 4       57645            89.40315   644.775905                    44409
#
#    Per capita income Geo_STATE
# 0              24644        01
# 1              26851        01
# 2              17350        01
# 3              18110        01
# 4              20501        01

# %%
#check the total population in the data
sum(demographics.Population)
# Out:
# 317746049

# %%
#add cumulative city income
demographics['Income']=demographics.Population*demographics['Per capita income']

# %% [markdown]
# ### Loading crime data (FBI 2014 estimates) obtained from social explorer

# %%
crime2014 = pd.read_csv('data/crime2014/R11460954_SL050.csv')
crime2014.head()
# Out:
#   Geo_FIPS        Geo_NAME                Geo_QNAME  Geo_STATE Geo_COUNTY  \
# 0    01001  Autauga County  Autauga County, Alabama          1        001
# 1    01003  Baldwin County  Baldwin County, Alabama          1        003
# 2    01005  Barbour County  Barbour County, Alabama          1        005
# 3    01007     Bibb County     Bibb County, Alabama          1        007
# 4    01009   Blount County   Blount County, Alabama          1        009
#
#    SE_T001_001  SE_T002_001  SE_T002_002  SE_T002_003  SE_T003_001  \
# 0      55395.0          482           68          414   870.114631
# 1     200111.0          760           98          662   379.789217
# 2      26887.0          145           17          128   539.294083
# 3      22506.0           86            4           82   382.120323
# 4      57719.0         1013           90          923  1755.054661
#
#       ...       SE_T006_001  SE_T006_002  SE_T006_003  SE_T006_004  \
# 0     ...               414        170.0        199.0         45.0
# 1     ...               662        230.0        405.0         27.0
# 2     ...               128         68.0         55.0          5.0
# 3     ...                82         42.0         34.0          6.0
# 4     ...               923        311.0        524.0         88.0
#
#    SE_T007_001  SE_T007_002  SE_T007_003  SE_T007_004  SE_T008_001  \
# 0   747.359870   306.886903   359.238198    81.234768          NaN
# 1   330.816397   114.936210   202.387675    13.492512          NaN
# 2   476.066501   252.910328   204.559824    18.596348          NaN
# 3   364.347285   186.616902   151.070826    26.659557          NaN
# 4  1599.126804   538.817374   907.846636   152.462794          NaN
#
#    SE_T009_001
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 34 columns]

# %%
crime2014.columns
# Out:
# Index(['Geo_FIPS', 'Geo_NAME', 'Geo_QNAME', 'Geo_STATE', 'Geo_COUNTY',
#        'SE_T001_001', 'SE_T002_001', 'SE_T002_002', 'SE_T002_003',
#        'SE_T003_001', 'SE_T003_002', 'SE_T003_003', 'SE_T004_001',
#        'SE_T004_002', 'SE_T004_003', 'SE_T004_004', 'SE_T004_005',
#        'SE_T004_006', 'SE_T005_001', 'SE_T005_002', 'SE_T005_003',
#        'SE_T005_004', 'SE_T005_005', 'SE_T005_006', 'SE_T006_001',
#        'SE_T006_002', 'SE_T006_003', 'SE_T006_004', 'SE_T007_001',
#        'SE_T007_002', 'SE_T007_003', 'SE_T007_004', 'SE_T008_001',
#        'SE_T009_001'],
#       dtype='object')

# %%
crime2014.rename(columns = { u'SE_T001_001' : 'Population',\
                             u'SE_T002_001' : 'Crimes',\
                          u'SE_T002_002' : 'Violent Crimes', \
                          u'SE_T002_003' : 'Property Crimes' }, inplace=True)

crime2014 = crime2014[[u'Geo_FIPS', u'Geo_NAME', u'Geo_QNAME', u'Geo_STATE', u'Geo_COUNTY', 'Population', 'Crimes' , 'Violent Crimes', 'Property Crimes']]

# %%
#the dataset does not cover entire country
sum(crime2014.Population)
# Out:
# 250424654.0

# %%
crime2014.head()
# Out:
#   Geo_FIPS        Geo_NAME                Geo_QNAME  Geo_STATE Geo_COUNTY  \
# 0    01001  Autauga County  Autauga County, Alabama          1        001
# 1    01003  Baldwin County  Baldwin County, Alabama          1        003
# 2    01005  Barbour County  Barbour County, Alabama          1        005
# 3    01007     Bibb County     Bibb County, Alabama          1        007
# 4    01009   Blount County   Blount County, Alabama          1        009
#
#    Population  Crimes  Violent Crimes  Property Crimes
# 0     55395.0     482              68              414
# 1    200111.0     760              98              662
# 2     26887.0     145              17              128
# 3     22506.0      86               4               82
# 4     57719.0    1013              90              923

# %% [markdown]
# #### Merging dataframes on GeoID (GeoID is used to uniquely identify a geographical location by the census bureau) for further analysis where crime and demographics are needed together

# %%
demographics['Geo_FIPS'] = demographics.Geo_GEOID.apply(lambda x: x[-5:]) #ensure consistent formatting of the geo id
df = pd.merge(demographics, crime2014, on='Geo_FIPS', how='inner') 
df.head()
# Out:
#       Geo_GEOID               Geo_NAME_x                Geo_QName  \
# 0  05000US01001  Autauga County, Alabama  Autauga County, Alabama
# 1  05000US01003  Baldwin County, Alabama  Baldwin County, Alabama
# 2  05000US01005  Barbour County, Alabama  Barbour County, Alabama
# 3  05000US01007     Bibb County, Alabama     Bibb County, Alabama
# 4  05000US01009   Blount County, Alabama   Blount County, Alabama
#
#    Geo_COUNTY_x  Population_x  Population Density         Area  \
# 0             1         55136            92.75346   594.436089
# 1             3        191205           120.27100  1589.784070
# 2             5         27119            30.64722   884.876304
# 3             7         22653            36.38555   622.582332
# 4             9         57645            89.40315   644.775905
#
#    Median household income  Per capita income Geo_STATE_x      Income  \
# 0                    52475              24644          01  1358771584
# 1                    50183              26851          01  5134045455
# 2                    35634              17350          01   470514650
# 3                    37984              18110          01   410245830
# 4                    44409              20501          01  1181780145
#
#   Geo_FIPS      Geo_NAME_y                Geo_QNAME  Geo_STATE_y Geo_COUNTY_y  \
# 0    01001  Autauga County  Autauga County, Alabama            1          001
# 1    01003  Baldwin County  Baldwin County, Alabama            1          003
# 2    01005  Barbour County  Barbour County, Alabama            1          005
# 3    01007     Bibb County     Bibb County, Alabama            1          007
# 4    01009   Blount County   Blount County, Alabama            1          009
#
#    Population_y  Crimes  Violent Crimes  Property Crimes
# 0       55395.0     482              68              414
# 1      200111.0     760              98              662
# 2       26887.0     145              17              128
# 3       22506.0      86               4               82
# 4       57719.0    1013              90              923

# %%
#select filed needed for the analysis
df=df[['Geo_STATE_x','Population_x','Area','Crimes','Violent Crimes','Property Crimes','Income', 'Per capita income']]
df.rename(columns = { 'Population_x' : 'Population', 'Geo_STATE_x' : 'Geo_State'}, inplace=True)
df.head()
# Out:
#   Geo_State  Population         Area  Crimes  Violent Crimes  Property Crimes  \
# 0        01       55136   594.436089     482              68              414
# 1        01      191205  1589.784070     760              98              662
# 2        01       27119   884.876304     145              17              128
# 3        01       22653   622.582332      86               4               82
# 4        01       57645   644.775905    1013              90              923
#
#        Income  Per capita income
# 0  1358771584              24644
# 1  5134045455              26851
# 2   470514650              17350
# 3   410245830              18110
# 4  1181780145              20501

# %% [markdown]
# ## Q1. Relations between Crime, Wealth and Density (county-level)

# %% [markdown]
# Q11. Run a linear regression of total Crime and total Income against population (without intercept). Visualize the data (scatter plots) and regression fit

# %%
income = df.Income
crimes = df.Crimes

x = income

y = crimes

fit = np.polyfit(x,y,1)
fit_fn = np.poly1d(fit)

plt.figure(figsize=(20,10))

plt.plot(x,y, 'yo', x, fit_fn(x), '--k')
# Out:
# [<matplotlib.lines.Line2D at 0x11aa8d8d0>,
#  <matplotlib.lines.Line2D at 0x11aa8da90>]

# %% [markdown]
# Q12. Analyze correlations between income per capita, population density, crime per capita, fraction of violent crime

# %%
# creating population density column (even though it was already in original data)

# incPerCap = df['Per capita income']
df['popDensity'] = df['Population']/df['Area']
df['crimePerCap'] = df.Crimes/df.Population
df['violentPerc'] = df['Violent Crimes']/df.Crimes
# popDensity = df['popDensity']
df.head()
# Out:
#   Geo_State  Population         Area  Crimes  Violent Crimes  Property Crimes  \
# 0        01       55136   594.436089     482              68              414
# 1        01      191205  1589.784070     760              98              662
# 2        01       27119   884.876304     145              17              128
# 3        01       22653   622.582332      86               4               82
# 4        01       57645   644.775905    1013              90              923
#
#        Income  Per capita income  popDensity  crimePerCap  violentPerc
# 0  1358771584              24644   92.753453     0.008742     0.141079
# 1  5134045455              26851  120.271050     0.003975     0.128947
# 2   470514650              17350   30.647221     0.005347     0.117241
# 3   410245830              18110   36.385549     0.003796     0.046512
# 4  1181780145              20501   89.403155     0.017573     0.088845

# %%
# df_less = pd.DataFrame(data=(df['Per capita income'], df['popDensity'], df['crimePerCap'], df['violentPerc'])
df.corr()
# Out:
#                    Population      Area    Crimes  Violent Crimes  \
# Population           1.000000  0.121144  0.560309        0.612075
# Area                 0.121144  1.000000  0.073050        0.085858
# Crimes               0.560309  0.073050  1.000000        0.967084
# Violent Crimes       0.612075  0.085858  0.967084        1.000000
# Property Crimes      0.547115  0.070242  0.998955        0.954446
# Income               0.986947  0.095584  0.521797        0.569486
# Per capita income    0.220941 -0.008737  0.093649        0.075210
# popDensity           0.528455 -0.086796  0.259955        0.243494
# crimePerCap         -0.093970 -0.048200  0.190354        0.150316
# violentPerc          0.063718  0.072996 -0.015617        0.041413
#
#                    Property Crimes    Income  Per capita income  popDensity  \
# Population                0.547115  0.986947           0.220941    0.528455
# Area                      0.070242  0.095584          -0.008737   -0.086796
# Crimes                    0.998955  0.521797           0.093649    0.259955
# Violent Crimes            0.954446  0.569486           0.075210    0.243494
# Property Crimes           1.000000  0.509603           0.096309    0.261103
# Income                    0.509603  1.000000           0.282335    0.560843
# Per capita income         0.096309  0.282335           1.000000    0.288002
# popDensity                0.261103  0.560843           0.288002    1.000000
# crimePerCap               0.196220 -0.106013          -0.154574   -0.111952
# violentPerc              -0.025754  0.070481          -0.012277    0.090974
#
#                    crimePerCap  violentPerc
# Population           -0.093970     0.063718
# Area                 -0.048200     0.072996
# Crimes                0.190354    -0.015617
# Violent Crimes        0.150316     0.041413
# Property Crimes       0.196220    -0.025754
# Income               -0.106013     0.070481
# Per capita income    -0.154574    -0.012277
# popDensity           -0.111952     0.090974
# crimePerCap           1.000000    -0.126602
# violentPerc          -0.126602     1.000000

# %% [markdown]
# ## Q2 Visualize characteristics of states
# ### Q2.1 Visualize income and population density per state

# %% [markdown]
# Aggregate demographics data per state

# %%
states = demographics.groupby(by='Geo_STATE').sum().loc[:,[u'Population', u'Area', \
                                                 u'Income']]

states.reset_index(inplace=True)

# %%
# why is the df 52 rows long? DC and PR?
print(len(states))
states.head()
# Out:
# 52
#   Geo_STATE  Population           Area         Income
# 0        01     4817678   50645.326381   115316134026
# 1        02      728300  570640.949601    24128028977
# 2        04     6561516  113594.083902   167558784896
# 3        05     2947036   52035.476971    66589385271
# 4        06    38066920  155779.218854  1138429083472

# %%
#function for visualizing spatial data (heatmap)
#import libraries for handing shapefiles
import shapefile as shp
from shapely.geometry.polygon import Polygon
from descartes import PolygonPatch

sf = shp.Reader('data/USA_adm/USA_states_reduced.shp')
sf_records=sf.records()
sf_shape=sf.shapeRecords()

#for plotting our result
def plot_spatial_distribution(x,t,logscale,n=200):
    # x - quantity to visualize, t - title, n - color granularity
    center=[]
    cmap = plt.cm.cool(np.linspace(0,1,n+1))
    
    if logscale:
      v2=np.log(max(x))
      v1=np.log(min(x))
    else:
      v2=max(x)
      v1=min(x)

    fig = plt.figure(figsize = (15,10)) 
    ax = fig.gca() 
    for s in range(0,len(sf_records)):
            v = x[s]
            if logscale:
              k = int((np.log(v)-v1)/(v2-v1)*n) # for the log-scale
            else:
              k = int(1.0*(v-v1)/(v2-v1)*n)
            c=cmap[k][0:3]

            shape=sf_shape[s]
            x_ = [i[0] for i in shape.shape.points[:]]
            y_ = [i[1] for i in shape.shape.points[:]]
            poly=Polygon(zip(x_,y_))
            temp=[poly.centroid.x,poly.centroid.y,k]
            center.append(temp)

            ax.add_patch(PolygonPatch(poly, fc=c,ec="k", alpha=1, zorder=2 ))
    center=pd.DataFrame(center)
    center.columns=["x","y","z"]
    sc = plt.scatter(center.x, center.y,c=list(center.z),cmap=plt.cm.cool)
    #plt.colorbar(sc)
    plt.title("Spatial distribution of "+t)
    plt.show()

# %%
Density=states.Population/states.Area
plot_spatial_distribution(Density,'density',1)

# %%
Wealth=states.Income/states.Population
plot_spatial_distribution(Wealth,'wealth',0)

# %% [markdown]
# ### Q2.2. Report top 5 and last 5 states by population density and income per capita

# %%
states['popDensity'] = states.Population/states.Area
states.sort('popDensity', ascending=False)
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#    Geo_STATE  Population           Area         Income    popDensity
# 8         11      633736      61.048425    29469991472  10380.873883
# 30        34     8874374    7354.220001   322663122147   1206.704994
# 51        72     3638965    3423.775148    41232200152   1062.851631
# 39        44     1053252    1033.814215    32402980403   1018.802009
# 21        25     6657291    7800.058431   242596287223    853.492452
# 6         09     3592053    4842.355124   138220869033    741.798754
# 20        24     5887776    9707.241263   215905053110    606.534425
# 7         10      917060    1948.543292    27686908955    470.638761
# 32        36    19594330   47126.398671   643260738841    415.782461
# 9         12    19361792   53624.758873   513061371262    361.060682
# 38        42    12758729   44742.702882   368884361938    285.157762
# 35        39    11560380   40860.694076   306583991715    282.921773
# 4         06    38066920  155779.218854  1138429083472    244.364558
# 13        17    12868747   55518.929712   386311407515    231.790257
# 14  24953.324364
# 42  24810.938214
# 18  24774.948375
# 36  24694.618891
# 44  24312.199370
# 40  24222.174631
# 31  23947.636777
# 0   23936.040148
# 17  23740.584534
# 48  23236.526849
# 12  23086.535307
# 3   22595.375581
# 24  20955.572088
# 51  11330.749307

# %% [markdown]
# ### Q2.3. Compute and visualize crime per capita and fraction of violent crimes per state. Report top and last 5 states in each

# %%
statesCrime = df.groupby(by='Geo_State').sum().loc[:,[u'Crimes', u'Population', \
                                                 u'Violent Crimes']]

statesCrime.reset_index(inplace=True)
statesCrime.head()
# Out:
#   Geo_State  Crimes  Population  Violent Crimes
# 0        01   25879     3495557            2978
# 1        04   25964     6208220            3047
# 2        05   23081     2701243            3135
# 3        06  124462    37237848           23881
# 4        08   18417     4151743            2398

# %%
statesCrime['CrimePerCap'] = statesCrime.Crimes/statesCrime.Population
statesCrime['ViolentFraction'] = statesCrime['Violent Crimes']/statesCrime.Crimes
statesCrime.head()
# Out:
#   Geo_State  Crimes  Population  Violent Crimes  CrimePerCap  ViolentFraction
# 0        01   25879     3495557            2978     0.007403         0.115074
# 1        04   25964     6208220            3047     0.004182         0.117355
# 2        05   23081     2701243            3135     0.008545         0.135826
# 3        06  124462    37237848           23881     0.003342         0.191874
# 4        08   18417     4151743            2398     0.004436         0.130206

# %%
crimePerCap =  statesCrime['CrimePerCap']
plot_spatial_distribution(crimePerCap,'CrimePerCap',0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-133-e8cd0fec1406> in <module>()
#       1 crimePerCap =  statesCrime['CrimePerCap']
# ----> 2 plot_spatial_distribution(crimePerCap,'CrimePerCap',0)
#
# <ipython-input-116-2c4994fb9b1a> in plot_spatial_distribution(x, t, logscale, n)
#      25     ax = fig.gca()
#      26     for s in range(0,len(sf_records)):
# ---> 27             v = x[s]
#      28             if logscale:
#      29               k = int((np.log(v)-v1)/(v2-v1)*n) # for the log-scale
#
# /anaconda/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     601         key = com._apply_if_callable(key, self)
#     602         try:
# --> 603             result = self.index.get_value(self, key)
#     604
#     605             if not is_scalar(result):
#
# /anaconda/lib/python3.6/site-packages/pandas/indexes/base.py in get_value(self, series, key)
#    2167         try:
#    2168             return self._engine.get_value(s, k,
# -> 2169                                           tz=getattr(series.dtype, 'tz', None))
#    2170         except KeyError as e1:
#    2171             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_value (pandas/index.c:3557)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_value (pandas/index.c:3240)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:8564)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:8508)()
#
# KeyError: 44

# %% [markdown]
# ## Q3 Urban scaling laws

# %% [markdown]
# ### Q3.1. Aggregate demographics and crime by MSA (separately)

# %%
msa = pd.read_csv('data/msalist.csv')
msa.head()

# %% [markdown]
# ### Q3.2. Establish a scaling relationship $Y\sim C X^q$ between total income and population. Visualize on the log scale. Does $q=1$ fall into the confidence interval?

# %% [markdown]
# ### Q3.3. Find the top 5 cities overperforming and underperforming cities by income (by log-scale difference from the trend)

# %% [markdown]
# ### Q3.4.Establish a scaling relationship $Y\sim C X^q$ between total, violent and property crime vs population. Visualize on the log scale. Does $q=1$ fall into the confidence interval? Find top 5 and last 5 cities by crime

# %% [markdown]
# ### Q3.5. Is there any relationship between residual by wealth and residual by crime?
